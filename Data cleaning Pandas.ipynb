# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',

'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# # 1

# %%
df["FlightNumber"][1] = 10055
df["FlightNumber"][3] = 10075
# Out:
# C:\Users\BNB\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\BNB\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df["FlightNumber"] = df["FlightNumber"].astype(int)

# %%
df["FlightNumber"].dtype
# Out:
# dtype('int32')

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# # 2

# %%
from_to = [df["From_To"][i].split(sep='_') for i in range(len(df))]
from_to
# Out:
# [['LoNDon', 'paris'],
#  ['MAdrid', 'miLAN'],
#  ['londON', 'StockhOlm'],
#  ['Budapest', 'PaRis'],
#  ['Brussels', 'londOn']]

# %%
temp = pd.DataFrame(from_to,columns=["From","To"])
temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# # 3

# %%
for i in range(len(temp)):
    temp["From"][i] = temp["From"][i].capitalize()
    temp["To"][i] = temp["To"][i].capitalize()

# %%
temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# # 4

# %%
df = df.drop(['From_To'],axis=1)

# %%
result = pd.concat([temp,df],axis=1)
result
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []    <Air France> (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# # 5

# %%
a = ["delay_1","delay_2","delay_3"]

# %%
b=list(result["RecentDelays"])
for i in b:
    for j in range(3-len(i)):
        i.append("NaN")

# %%
delays_dict = {i:j for i,j in zip(a,zip(*b))}
delays_dict
# Out:
# {'delay_1': (23, 'NaN', 24, 13, 67),
#  'delay_2': (47, 'NaN', 43, 'NaN', 32),
#  'delay_3': ('NaN', 'NaN', 87, 'NaN', 'NaN')}

# %%
delays = pd.DataFrame(delays_dict)
delays
# Out:
#   delay_1 delay_2 delay_3
# 0      23      47     NaN
# 1     NaN     NaN     NaN
# 2      24      43      87
# 3      13     NaN     NaN
# 4      67      32     NaN

# %%
result = result.drop("RecentDelays",axis=1)

# %%
result
# Out:
#        From         To  FlightNumber              Airline
# 0    London      Paris         10045               KLM(!)
# 1    Madrid      Milan         10055    <Air France> (12)
# 2    London  Stockholm         10065  (British Airways. )
# 3  Budapest      Paris         10075       12. Air France
# 4  Brussels     London         10085          "Swiss Air"

# %%
final_result = pd.concat([result,delays],axis =1)
final_result
# Out:
#        From         To  FlightNumber              Airline delay_1 delay_2  \
# 0    London      Paris         10045               KLM(!)      23      47
# 1    Madrid      Milan         10055    <Air France> (12)     NaN     NaN
# 2    London  Stockholm         10065  (British Airways. )      24      43
# 3  Budapest      Paris         10075       12. Air France      13     NaN
# 4  Brussels     London         10085          "Swiss Air"      67      32
#
#   delay_3
# 0     NaN
# 1     NaN
# 2      87
# 3     NaN
# 4     NaN
