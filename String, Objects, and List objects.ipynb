# %%
l = [1,2,3,4,5,4,3,2,1]
for i in range(9):
    for j in range(l[i]):
        print('*',end =' ')
    print('\n')
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %%
a = input("Enter a word ")
a[::-1]
# Out:
# Enter a word ineuron
# 'norueni'
